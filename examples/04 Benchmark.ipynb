# %% [markdown]
# # Reading CF1

# %%
import glob
import random

import src.radar as radar

# %%
files = glob.glob("/mnt/data/PX1000/2024/20241221/_original/*.txz")
assert len(files) > 0, "No files found"
file = files[random.randint(0, len(files) - 1)]
print(f"Selected file: {file}")
# Out:
# Selected file: /mnt/data/PX1000/2024/20241221/_original/PX-20241221-014643-E4.0.txz

# %%
# %timeit sweep = radar.read(file)
# Out:
# 658 ms ± 8.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
